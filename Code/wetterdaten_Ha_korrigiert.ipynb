# %% [markdown]
# # Get weather data

# %% [markdown]
# ## Imports and functions

# %%
import pandas as pd
import numpy as np

# Import Meteostat library and dependencies
from datetime import datetime
import matplotlib.pyplot as plt
from meteostat import Point, Daily

# %%
def get_time_period(df):
    year = df['year']

    start_month = int(4) if int(df['location']) == 1 else int(10)
    start = datetime(year, start_month, 1)

    end_month = int(10) if int(df['location']) == 1 else int(4)
    end_day = int(31) if int(df['location']) == 1 else int(30)
    end = datetime(year, end_month, end_day)

    return (start, end)

# %%
def get_temp_data(df):
    for index, row in df.iterrows():
        start, end = get_time_period(row)
        row_lat = float(row['lat'])
        row_lon = float(row['lon'])
        regions = Point(row_lat,row_lon)

        data = Daily(regions, start, end)
        data = data.fetch()

        data = data[['tavg', 'tmin', 'tmax', 'prcp', 'wspd', 'wpgt', 'tsun']]

        avg_temp = data['tavg'].mean()
        min_temp = data['tmin'].mean()
        max_temp = data['tmax'].mean()
        precipitation = data['prcp'].mean()
        wind_speed = data['wspd'].mean()
        wind_peak = data['wpgt'].mean()
        sunshine = data['tsun'].mean()

        df.at[index, 'avg_temp'] = avg_temp
        df.at[index, 'min_temp'] = min_temp
        df.at[index, 'max_temp'] = max_temp
        df.at[index, 'precipitation_in_mm'] = precipitation
        df.at[index, 'wind_average_kmh'] = wind_speed
        df.at[index, 'wind_peak_kmh'] = wind_peak
        df.at[index, 'sun_minutes'] = sunshine
        
    return df

# %%
def fix_geo_data(df, point):
    df['lat'] = df['lat'].replace(df['lat'].iloc[0], point._lat)
    df['lon'] = df['lon'].replace(df['lon'].iloc[0], point._lon)

    return df

# %% [markdown]
# ## Import csvs
# - winemag-data-130k-v2+extract.csv
# - winemag-data-130k-v2+geo.csv

# %%
df = pd.read_csv('../Data/winemag-data-130k-v2+extract.csv', sep=';')

# %%
df = df[['country','province','region_1','year']]

# %%
df_geo = pd.read_csv('../Data/winemag-data-130k-v2+geo.csv', sep=';', index_col=0)

# %%
df_geo = df_geo[['lat','lon']]

# %%
# will perform left join
result = df.join(df_geo)

# %%
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129971 entries, 0 to 129970
# Data columns (total 6 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   country   129908 non-null  object
#  1   province  129908 non-null  object
#  2   region_1  108724 non-null  object
#  3   year      129931 non-null  float64
#  4   lat       87966 non-null   float64
#  5   lon       87966 non-null   float64
# dtypes: float64(3), object(3)
# memory usage: 5.9+ MB

# %% [markdown]
# ### Drop duplicates

# %%
result = result.drop_duplicates()

# %%
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11683 entries, 0 to 129952
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   country   11682 non-null  object
#  1   province  11682 non-null  object
#  2   region_1  9199 non-null   object
#  3   year      11656 non-null  float64
#  4   lat       6211 non-null   float64
#  5   lon       6211 non-null   float64
# dtypes: float64(3), object(3)
# memory usage: 638.9+ KB

# %% [markdown]
# ### Subset - year between 1990 and 2017

# %%
result_year = result[(result["year"] >= 1990) & (result["year"] <= 2023)]

# %%
print(result_year.isnull().sum())
# Out:
# country        0
# province       0
# region_1    2132
# year           0
# lat         4770
# lon         4770
# dtype: int64

# %% [markdown]
# ### Drop NA values

# %%
df_year = result_year[result_year['lat'].notna()]

# %%
df_year.reset_index(inplace=True, drop=True)

# %%
df_year.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5074 entries, 0 to 5073
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   country   5074 non-null   object
#  1   province  5074 non-null   object
#  2   region_1  3937 non-null   object
#  3   year      5074 non-null   float64
#  4   lat       5074 non-null   float64
#  5   lon       5074 non-null   float64
# dtypes: float64(3), object(3)
# memory usage: 238.0+ KB

# %% [markdown]
# ### Fix data types

# %%
df_year['year'] = df_year['year'].astype('int')
# Out:
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
final_tb = df_year
final_tb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5074 entries, 0 to 5073
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   country   5074 non-null   object
#  1   province  5074 non-null   object
#  2   region_1  3937 non-null   object
#  3   year      5074 non-null   int32
#  4   lat       5074 non-null   float64
#  5   lon       5074 non-null   float64
# dtypes: float64(2), int32(1), object(3)
# memory usage: 218.1+ KB

# %% [markdown]
# ### Add new column "location"

# %%
# check if location is in north or south of the earth
lat_list = final_tb['lat']
location = []
for n in lat_list:
    if n >= 0:
        location.append(1)
    else:
        location.append(0)

final_tb['location'] = location
final_tb['location'] = final_tb['location'].astype('int')
# Out:
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
final_tb.to_csv("../Data/resource_table.csv")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In [21], line 1
# ----> 1 final_tb.to_csv("../Data/resource_table.csv")
#
# File c:\Users\ji_so\anaconda3\envs\stats\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File c:\Users\ji_so\anaconda3\envs\stats\lib\site-packages\pandas\core\generic.py:3720, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3709 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3711 formatter = DataFrameFormatter(
#    3712     frame=df,
#    3713     header=header,
#    (...)
#    3717     decimal=decimal,
#    3718 )
# -> 3720 return DataFrameRenderer(formatter).to_csv(
#    3721     path_or_buf,
#    3722     lineterminator=lineterminator,
#    3723     sep=sep,
#    3724     encoding=encoding,
#    3725     errors=errors,
#    3726     compression=compression,
#    3727     quoting=quoting,
#    3728     columns=columns,
#    3729     index_label=index_label,
#    3730     mode=mode,
#    3731     chunksize=chunksize,
#    3732     quotechar=quotechar,
#    3733     date_format=date_format,
#    3734     doublequote=doublequote,
#    3735     escapechar=escapechar,
#    3736     storage_options=storage_options,
#    3737 )
#
# File c:\Users\ji_so\anaconda3\envs\stats\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File c:\Users\ji_so\anaconda3\envs\stats\lib\site-packages\pandas\io\formats\format.py:1189, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1168     created_buffer = False
#    1170 csv_formatter = CSVFormatter(
#    1171     path_or_buf=path_or_buf,
#    1172     lineterminator=lineterminator,
#    (...)
#    1187     formatter=self.fmt,
#    1188 )
# -> 1189 csv_formatter.save()
#    1191 if created_buffer:
#    1192     assert isinstance(path_or_buf, StringIO)
#
# File c:\Users\ji_so\anaconda3\envs\stats\lib\site-packages\pandas\io\formats\csvs.py:241, in CSVFormatter.save(self)
#     237 """
#     238 Create the writer & save.
#     239 """
#     240 # apply compression and byte/text conversion
# --> 241 with get_handle(
#     242     self.filepath_or_buffer,
#     243     self.mode,
#     244     encoding=self.encoding,
#     245     errors=self.errors,
#     246     compression=self.compression,
#     247     storage_options=self.storage_options,
#     248 ) as handles:
#     249
#     250     # Note: self.encoding is irrelevant here
#     251     self.writer = csvlib.writer(
#     252         handles.handle,
#     253         lineterminator=self.lineterminator,
#    (...)
#     258         quotechar=self.quotechar,
#     259     )
#     261     self._save()
#
# File c:\Users\ji_so\anaconda3\envs\stats\lib\site-packages\pandas\io\common.py:856, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     851 elif isinstance(handle, str):
#     852     # Check whether the filename is to be opened in binary mode.
#     853     # Binary mode does not support 'encoding' and 'newline'.
#     854     if ioargs.encoding and "b" not in ioargs.mode:
#     855         # Encoding
# --> 856         handle = open(
#     857             handle,
#     858             ioargs.mode,
#     859             encoding=ioargs.encoding,
#     860             errors=errors,
#     861             newline="",
#     862         )
#     863     else:
#     864         # Binary mode
#     865         handle = open(handle, ioargs.mode)
#
# PermissionError: [Errno 13] Permission denied: '../Data/resource_table.csv'

# %% [markdown]
# ## Get temperature data

# %%
final_tb = pd.read_csv("../Data/resource_table.csv", index_col=0)

# %% [markdown]
# ### Test with an example

# %%
# Create Point for Vancouver, BC
start, end = get_time_period(final_tb[7:8])
vancouver = Point(49.2497, -123.1193, 70)
# Out:
# DeprecationWarning: an integer is required (got type Series).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
# DeprecationWarning: an integer is required (got type Series).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.

# %%
# Get daily data for year of first_row
data = Daily(vancouver, start, end)
data = data.fetch()
# Out:
# FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`

# %%
data
# Out:
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres  tsun
# time
# 2013-04-01  11.9   7.0  16.7   0.0   0.0    NaN  14.7   NaN  1017.5   NaN
# 2013-04-02  11.1   9.6  12.5   0.0   0.0  130.0  13.0   NaN  1022.0   NaN
# 2013-04-03  10.2   6.5  13.8   0.0   0.0    NaN   8.0   NaN  1020.6   NaN
# 2013-04-04  10.4   8.6  12.1  22.0   0.0    NaN   7.0   NaN  1007.8   NaN
# 2013-04-05   9.7   8.6  10.7  14.8   0.0  130.0  16.5   NaN  1007.3   NaN
# ...          ...   ...   ...   ...   ...    ...   ...   ...     ...   ...
# 2013-10-27  11.4   8.5  14.3   1.6   NaN    NaN  13.3   NaN  1016.6   NaN
# 2013-10-28  11.4   7.5  15.3   0.0   NaN    NaN   9.6   NaN  1016.5   NaN
# 2013-10-29   8.0   3.9  12.1   0.0   NaN    NaN   8.7   NaN  1016.0   NaN
# 2013-10-30   9.8   6.5  13.0   4.0   0.0   91.0  14.6   NaN  1018.8   NaN
# 2013-10-31   9.0   8.2   9.8   5.8   NaN    NaN  10.3   NaN  1021.4   NaN
#
# [214 rows x 10 columns]

# %%
avg_temp = data['tavg'].mean()
avg_temp
# Out:
# 14.715420560747665

# %%
min_temp = data['tmin'].min()
min_temp
# Out:
# 2.1

# %%
max_temp = data['tmax'].max()
max_temp
# Out:
# 30.8

# %% [markdown]
# ### Get data with function

# %%
data = final_tb[7:8]
result = get_temp_data(data)
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1 entries, 7 to 7
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   index                1 non-null      int64
#  1   country              1 non-null      object
#  2   province             1 non-null      object
#  3   region_1             0 non-null      object
#  4   year                 1 non-null      int64
#  5   lat                  1 non-null      float64
#  6   lon                  1 non-null      float64
#  7   location             1 non-null      int64
#  8   avg_temp             1 non-null      float64
#  9   min_temp             1 non-null      float64
#  10  max_temp             1 non-null      float64
#  11  precipitation_in_mm  1 non-null      float64
#  12  wind_average_kmh     1 non-null      float64
#  13  wind_peak_kmh        0 non-null      float64
#  14  sun_minutes          0 non-null      float64
# dtypes: float64(9), int64(3), object(3)
# memory usage: 236.0+ bytes
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
final_tb = get_temp_data(final_tb)
final_tb
# Out:
# Warning: Cannot load daily/LIER0.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load daily/08552.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load daily/11195.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load daily/11011.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load daily/94784.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load daily/16714.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load daily/11191.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load daily/LIPG0.csv.gz from https://bulk.meteostat.net/v2/
#        index   country           province                            region_1  \
# 0          0     Italy  Sicily & Sardinia                                Etna
# 1          1  Portugal              Douro                                 NaN
# 2          2        US             Oregon                   Willamette Valley
# 3          3        US           Michigan                 Lake Michigan Shore
# 4          4        US             Oregon                   Willamette Valley
# ...      ...       ...                ...                                 ...
# 5069  129618        US         California                  San Antonio Valley
# 5070  129820    Greece         Goumenissa                                 NaN
# 5071  129933   Austria            Austria                                 NaN
# 5072  129935        US         Washington  Columbia Valley-Walla Walla Valley
# 5073  129952        US         California                       Chiles Valley
#
#       year        lat         lon  location   avg_temp   min_temp   max_temp  \
# 0     2013  40.047396    8.286983         1        NaN        NaN        NaN
# 1     2011  39.886265   -8.268731         1  19.021028  13.725503  26.029717
# 2     2013  45.420675 -122.670649         1  16.361215  11.382710  22.425234
# 3     2013  41.707539  -86.895030         1  16.006103  10.642254  21.388732
# 4     2012  45.420675 -122.670649         1  16.184579  11.049533  22.211215
# ...    ...        ...         ...       ...        ...        ...        ...
# 5069  2009  38.628683  -92.565963         1        NaN        NaN        NaN
# 5070  2008  40.946644   22.451941         1        NaN        NaN        NaN
# 5071  2005  47.835690   14.221708         1  14.865888  10.711215  20.398131
# 5072  2006  38.895037  -77.036543         1  20.551174  15.824299  25.646729
# 5073  2011  38.628683  -92.565963         1        NaN        NaN        NaN
#
#       precipitation_in_mm  wind_average_kmh  wind_peak_kmh  sun_minutes
# 0                     NaN               NaN            NaN          NaN
# 1                9.736842               NaN            NaN          NaN
# 2                1.881776          9.025701            NaN          NaN
# 3                0.778358          8.595283            NaN          NaN
# 4                2.032710          9.443458            NaN          NaN
# ...                   ...               ...            ...          ...
# 5069                  NaN               NaN            NaN          NaN
# 5070                  NaN               NaN            NaN          NaN
# 5071             3.568224               NaN            NaN          NaN
# 5072             4.190654         13.424299            NaN          NaN
# 5073                  NaN               NaN            NaN          NaN
#
# [5074 rows x 15 columns]

# %%
final_tb.head(30)
# Out:
#     index   country           province               region_1  year  \
# 0       0     Italy  Sicily & Sardinia                   Etna  2013
# 1       1  Portugal              Douro                    NaN  2011
# 2       2        US             Oregon      Willamette Valley  2013
# 3       3        US           Michigan    Lake Michigan Shore  2013
# 4       4        US             Oregon      Willamette Valley  2012
# 5       6     Italy  Sicily & Sardinia               Vittoria  2013
# 6       7    France             Alsace                 Alsace  2012
# 7       8   Germany        Rheinhessen                    NaN  2013
# 8      10        US         California            Napa Valley  2011
# 9      12        US         California       Alexander Valley  2012
# 10     13     Italy  Sicily & Sardinia                   Etna  2012
# 11     14        US         California          Central Coast  2012
# 12     15   Germany              Mosel                    NaN  2013
# 13     19        US           Virginia               Virginia  2012
# 14     21        US             Oregon                 Oregon  2013
# 15     22     Italy  Sicily & Sardinia                Sicilia  2007
# 16     23        US         California            Paso Robles  2011
# 17     24     Italy  Sicily & Sardinia                Sicilia  2009
# 18     25        US         California           Sonoma Coast  2011
# 19     26     Italy  Sicily & Sardinia        Terre Siciliane  2013
# 20     28     Italy  Sicily & Sardinia  Cerasuolo di Vittoria  2011
# 21     29        US         California             Clarksburg  2010
# 22     30    France         Beaujolais    Beaujolais-Villages  2012
# 23     31     Italy  Sicily & Sardinia                Sicilia  2010
# 24     32     Italy  Sicily & Sardinia                Sicilia  2011
# 25     33        US         California       Dry Creek Valley  2010
# 26     34        US         California          Sonoma Valley  2011
# 27     35        US             Oregon            McMinnville  2010
# 28     41        US             Oregon      Willamette Valley  2009
# 29     42    France         Beaujolais             Beaujolais  2012
#
#           lat         lon  location   avg_temp   min_temp   max_temp  \
# 0   40.047396    8.286983         1        NaN        NaN        NaN
# 1   39.886265   -8.268731         1  19.021028  13.725503  26.029717
# 2   45.420675 -122.670649         1  16.361215  11.382710  22.425234
# 3   41.707539  -86.895030         1  16.006103  10.642254  21.388732
# 4   45.420675 -122.670649         1  16.184579  11.049533  22.211215
# 5   40.047396    8.286983         1        NaN        NaN        NaN
# 6   48.684873    2.175608         1  14.992991  11.049533  19.220093
# 7   49.904518    8.271108         1  13.610748   9.766355  17.928037
# 8   38.628683  -92.565963         1        NaN        NaN        NaN
# 9   38.628683  -92.565963         1        NaN        NaN        NaN
# 10  40.047396    8.286983         1        NaN        NaN        NaN
# 11  38.628683  -92.565963         1        NaN        NaN        NaN
# 12  50.781026   12.478017         1  13.882710   8.854206  18.853738
# 13  47.523260  -92.536571         1  13.019905   6.109005  19.597156
# 14  45.420675 -122.670649         1  16.361215  11.382710  22.425234
# 15  40.047396    8.286983         1        NaN        NaN        NaN
# 16  38.628683  -92.565963         1        NaN        NaN        NaN
# 17  40.047396    8.286983         1        NaN        NaN        NaN
# 18  38.628683  -92.565963         1        NaN        NaN        NaN
# 19  40.047396    8.286983         1        NaN        NaN        NaN
# 20  40.047396    8.286983         1        NaN        NaN        NaN
# 21  38.628683  -92.565963         1        NaN        NaN        NaN
# 22  46.118612    4.615671         1  16.122599  11.626554  21.303390
# 23  40.047396    8.286983         1        NaN        NaN        NaN
# 24  40.047396    8.286983         1        NaN        NaN        NaN
# 25  38.628683  -92.565963         1        NaN        NaN        NaN
# 26  38.628683  -92.565963         1        NaN        NaN        NaN
# 27  45.420675 -122.670649         1  15.205140  10.563084  20.819626
# 28  45.420675 -122.670649         1  16.876636  11.555607  23.129907
# 29  46.118612    4.615671         1  16.122599  11.626554  21.303390
#
#     precipitation_in_mm  wind_average_kmh  wind_peak_kmh  sun_minutes
# 0                   NaN               NaN            NaN          NaN
# 1              9.736842               NaN            NaN          NaN
# 2              1.881776          9.025701            NaN          NaN
# 3              0.778358          8.595283            NaN          NaN
# 4              2.032710          9.443458            NaN          NaN
# 5                   NaN               NaN            NaN          NaN
# 6              2.139720         11.940952            NaN          NaN
# 7              1.964019          8.819340            NaN          NaN
# 8                   NaN               NaN            NaN          NaN
# 9                   NaN               NaN            NaN          NaN
# 10                  NaN               NaN            NaN          NaN
# 11                  NaN               NaN            NaN          NaN
# 12             2.809813               NaN            NaN          NaN
# 13             0.359184          9.111792            NaN          NaN
# 14             1.881776          9.025701            NaN          NaN
# 15                  NaN               NaN            NaN          NaN
# 16                  NaN               NaN            NaN          NaN
# 17                  NaN               NaN            NaN          NaN
# 18                  NaN               NaN            NaN          NaN
# 19                  NaN               NaN            NaN          NaN
# 20                  NaN               NaN            NaN          NaN
# 21                  NaN               NaN            NaN          NaN
# 22                  NaN          8.565909            NaN          NaN
# 23                  NaN               NaN            NaN          NaN
# 24                  NaN               NaN            NaN          NaN
# 25                  NaN               NaN            NaN          NaN
# 26                  NaN               NaN            NaN          NaN
# 27             2.368224          9.773832            NaN          NaN
# 28             1.475701          9.879907            NaN          NaN
# 29                  NaN          8.565909            NaN          NaN

# %% [markdown]
# #### Check null values

# %%
final_tb["avg_temp"].isnull().sum()
# Out:
# 3352

# %%
final_tb["sun_minutes"].isnull().sum()
# Out:
# 4951

# %%
len(final_tb)
# Out:
# 5074

# %%
final_tb.to_csv('../Data/temp_table.csv')

# %% [markdown]
# ## Handling missing values

# %%
final_tb = pd.read_csv('../Data/temp_table.csv', index_col=0) 
final_tb['location'] = final_tb['location'].astype('int')
final_tb['year'] = final_tb['year'].astype('int')

# %%
final_tb.isnull().sum()
# Out:
# index                     0
# country                   0
# province                  0
# region_1               1137
# year                      0
# lat                       0
# lon                       0
# location                  0
# avg_temp               3352
# min_temp               3348
# max_temp               3349
# precipitation_in_mm    3662
# wind_average_kmh       3501
# wind_peak_kmh          5021
# sun_minutes            4951
# dtype: int64

# %% [markdown]
# ### 1. Country = US & Province = California
# - Check, whether the given geo-coordinates work. If it doesn't work, we should find another geo-coordinates and run the temperature code
#     - Original geo-coordinates
#         - lat = 38.628683
#         - lon = -92.565963
#     - New geo-coordinates
#         - lat = 36.778259
#         - lon = -119.417931

# %%
wrong_geo = final_tb[(final_tb["province"] == "California") & (final_tb['avg_temp'].isna() ==True)]
fix_geo_data(wrong_geo, Point(36.778259,-119.417931))
final_tb.update(wrong_geo)
# Out:
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
final_tb[(final_tb["country"] == "US") & (final_tb["province"] =="California")]
# Out:
#          index country    province                            region_1  \
# 8         10.0      US  California                         Napa Valley
# 9         12.0      US  California                    Alexander Valley
# 11        14.0      US  California                       Central Coast
# 16        23.0      US  California                         Paso Robles
# 18        25.0      US  California                        Sonoma Coast
# ...        ...     ...         ...                                 ...
# 5060  128256.0      US  California                 Contra Costa County
# 5062  128986.0      US  California                         Napa-Sonoma
# 5065  129214.0      US  California  San Francisco Bay-Livermore Valley
# 5069  129618.0      US  California                  San Antonio Valley
# 5073  129952.0      US  California                       Chiles Valley
#
#         year        lat         lon  location  avg_temp  min_temp  max_temp  \
# 8     2011.0  36.778259 -119.417931       1.0       NaN       NaN       NaN
# 9     2012.0  36.778259 -119.417931       1.0       NaN       NaN       NaN
# 11    2012.0  36.778259 -119.417931       1.0       NaN       NaN       NaN
# 16    2011.0  36.778259 -119.417931       1.0       NaN       NaN       NaN
# 18    2011.0  36.778259 -119.417931       1.0       NaN       NaN       NaN
# ...      ...        ...         ...       ...       ...       ...       ...
# 5060  2008.0  36.778259 -119.417931       1.0       NaN       NaN       NaN
# 5062  2008.0  36.778259 -119.417931       1.0       NaN       NaN       NaN
# 5065  2009.0  36.778259 -119.417931       1.0       NaN       NaN       NaN
# 5069  2009.0  36.778259 -119.417931       1.0       NaN       NaN       NaN
# 5073  2011.0  36.778259 -119.417931       1.0       NaN       NaN       NaN
#
#       precipitation_in_mm  wind_average_kmh  wind_peak_kmh  sun_minutes
# 8                     NaN               NaN            NaN          NaN
# 9                     NaN               NaN            NaN          NaN
# 11                    NaN               NaN            NaN          NaN
# 16                    NaN               NaN            NaN          NaN
# 18                    NaN               NaN            NaN          NaN
# ...                   ...               ...            ...          ...
# 5060                  NaN               NaN            NaN          NaN
# 5062                  NaN               NaN            NaN          NaN
# 5065                  NaN               NaN            NaN          NaN
# 5069                  NaN               NaN            NaN          NaN
# 5073                  NaN               NaN            NaN          NaN
#
# [1585 rows x 15 columns]

# %% [markdown]
# ### 2. Country = Italy & Province = Sicily & Sardinia
# - Check, whether the given geo-coordinates work. If it doesn't work, we should find another geo-coordinates and run the temperature code
#
#     - Original geo-coordinates
#         - lat = 40.047396
#         - lon = 8.286983
#     - New geo-coordinates
#         - lat = 39.373062
#         - lon = 9.157212

# %%
wrong_geo = final_tb[(final_tb["province"] == "Sicily & Sardinia") & (final_tb['avg_temp'].isna() ==True)]
fix_geo_data(wrong_geo, Point(39.373062,9.157212))
final_tb.update(wrong_geo)
# Out:
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
final_tb[(final_tb["province"] == "Sicily & Sardinia") & (final_tb['avg_temp'].isna() ==True)]
# Out:
#          index country           province                region_1    year  \
# 0          0.0   Italy  Sicily & Sardinia                    Etna  2013.0
# 5          6.0   Italy  Sicily & Sardinia                Vittoria  2013.0
# 10        13.0   Italy  Sicily & Sardinia                    Etna  2012.0
# 15        22.0   Italy  Sicily & Sardinia                 Sicilia  2007.0
# 17        24.0   Italy  Sicily & Sardinia                 Sicilia  2009.0
# ...        ...     ...                ...                     ...     ...
# 4934  117050.0   Italy  Sicily & Sardinia                 Alghero  2010.0
# 4960  119400.0   Italy  Sicily & Sardinia                   Erice  2013.0
# 4966  120030.0   Italy  Sicily & Sardinia   Malvasia delle Lipari  2010.0
# 5029  125237.0   Italy  Sicily & Sardinia      Contea di Sclafani  2014.0
# 5040  126240.0   Italy  Sicily & Sardinia  Passito di Pantelleria  2008.0
#
#             lat       lon  location  avg_temp  min_temp  max_temp  \
# 0     39.373062  9.157212       1.0       NaN       NaN       NaN
# 5     39.373062  9.157212       1.0       NaN       NaN       NaN
# 10    39.373062  9.157212       1.0       NaN       NaN       NaN
# 15    39.373062  9.157212       1.0       NaN       NaN       NaN
# 17    39.373062  9.157212       1.0       NaN       NaN       NaN
# ...         ...       ...       ...       ...       ...       ...
# 4934  39.373062  9.157212       1.0       NaN       NaN       NaN
# 4960  39.373062  9.157212       1.0       NaN       NaN       NaN
# 4966  39.373062  9.157212       1.0       NaN       NaN       NaN
# 5029  39.373062  9.157212       1.0       NaN       NaN       NaN
# 5040  39.373062  9.157212       1.0       NaN       NaN       NaN
#
#       precipitation_in_mm  wind_average_kmh  wind_peak_kmh  sun_minutes
# 0                     NaN               NaN            NaN          NaN
# 5                     NaN               NaN            NaN          NaN
# 10                    NaN               NaN            NaN          NaN
# 15                    NaN               NaN            NaN          NaN
# 17                    NaN               NaN            NaN          NaN
# ...                   ...               ...            ...          ...
# 4934                  NaN               NaN            NaN          NaN
# 4960                  NaN               NaN            NaN          NaN
# 4966                  NaN               NaN            NaN          NaN
# 5029                  NaN               NaN            NaN          NaN
# 5040                  NaN               NaN            NaN          NaN
#
# [192 rows x 15 columns]

# %% [markdown]
# ### 3. Country = Australia & Province = South Australia
# - Check, whether the given geo-coordinates work. If it doesn't work, we should find another geo-coordinates and run the temperature code
#
#     - Original geo-coordinates
#         - lat = -34.741121
#         - lon = 138.656437
#     - New geo-coordinates
#         - lat = 39.373062
#         - lon = 9.157212

# %%
wrong_geo = final_tb[(final_tb["province"] == "South Australia") & (final_tb['avg_temp'].isna() ==True)]
fix_geo_data(wrong_geo, Point(-34.064999, 150.814163))
final_tb.update(wrong_geo)
# Out:
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# ### 4. Country = Portugal & Province = Tejo
# - Check, whether the given geo-coordinates work. If it doesn't work, we should find another geo-coordinates and run the temperature code
#
#     - Original geo-coordinates
#         - lat = 39.409227
#         - lon = -8.205827
#     - New geo-coordinates
#         - lat = 38.74908340
#         - lon = -9.13983090

# %%
wrong_geo = final_tb[(final_tb["province"] == "Tejo") & (final_tb['avg_temp'].isna() ==True)]
fix_geo_data(wrong_geo, Point(38.74908340,-9.13983090))
final_tb.update(wrong_geo)
# Out:
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
final_tb[(final_tb["province"] == "Tejo") & (final_tb['avg_temp'].isna() ==True)]
# Out:
#         index   country province region_1    year        lat       lon  \
# 50       79.0  Portugal     Tejo      NaN  2014.0  38.749083 -9.139831
# 299     646.0  Portugal     Tejo      NaN  2013.0  38.749083 -9.139831
# 395     921.0  Portugal     Tejo      NaN  2015.0  38.749083 -9.139831
# 606    1617.0  Portugal     Tejo      NaN  2016.0  38.749083 -9.139831
# 697    2033.0  Portugal     Tejo      NaN  2012.0  38.749083 -9.139831
# 824    2652.0  Portugal     Tejo      NaN  2009.0  38.749083 -9.139831
# 865    2866.0  Portugal     Tejo      NaN  2011.0  38.749083 -9.139831
# 1232   4916.0  Portugal     Tejo      NaN  2010.0  38.749083 -9.139831
# 2290  15028.0  Portugal     Tejo      NaN  2008.0  38.749083 -9.139831
# 2956  27267.0  Portugal     Tejo      NaN  2007.0  38.749083 -9.139831
#
#       location  avg_temp  min_temp  max_temp  precipitation_in_mm  \
# 50         1.0       NaN       NaN       NaN                  NaN
# 299        1.0       NaN       NaN       NaN                  NaN
# 395        1.0       NaN       NaN       NaN                  NaN
# 606        1.0       NaN       NaN       NaN                  NaN
# 697        1.0       NaN       NaN       NaN                  NaN
# 824        1.0       NaN       NaN       NaN                  NaN
# 865        1.0       NaN       NaN       NaN                  NaN
# 1232       1.0       NaN       NaN       NaN                  NaN
# 2290       1.0       NaN       NaN       NaN                  NaN
# 2956       1.0       NaN       NaN       NaN                  NaN
#
#       wind_average_kmh  wind_peak_kmh  sun_minutes
# 50                 NaN            NaN          NaN
# 299                NaN            NaN          NaN
# 395                NaN            NaN          NaN
# 606                NaN            NaN          NaN
# 697                NaN            NaN          NaN
# 824                NaN            NaN          NaN
# 865                NaN            NaN          NaN
# 1232               NaN            NaN          NaN
# 2290               NaN            NaN          NaN
# 2956               NaN            NaN          NaN

# %% [markdown]
# ### 5. Country = Greece & Province = Naoussa
# - Check, whether the given geo-coordinates work. If it doesn't work, we should find another geo-coordinates and run the temperature code
#     - Geo-coordinates have been adjusted

# %%
wrong_geo = final_tb[(final_tb["province"] == "Naoussa") & (final_tb['avg_temp'].isna() ==True)]
fix_geo_data(wrong_geo, Point(40.6308695, 40.428022))
final_tb.update(wrong_geo)
# Out:
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# ### 6. Country = Greece & Province = Nemea
# - Check, whether the given geo-coordinates work. If it doesn't work, we should find another geo-coordinates and run the temperature code
#     - Geo-coordinates have been adjusted

# %%
wrong_geo = final_tb[(final_tb["country"] == "Greece") & (final_tb["province"] == "Nemea")]
fix_geo_data(wrong_geo, Point(37.955894,23.702099))
final_tb.update(wrong_geo)
# Out:
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
final_tb[(final_tb["country"] == "Greece") & (final_tb["province"] == "Nemea")]
# Out:
#         index country province region_1    year        lat        lon  \
# 732    2166.0  Greece    Nemea      NaN  2012.0  37.955894  23.702099
# 1211   4794.0  Greece    Nemea      NaN  2008.0  37.955894  23.702099
# 1804   9345.0  Greece    Nemea      NaN  2004.0  37.955894  23.702099
# 1908  10489.0  Greece    Nemea      NaN  2011.0  37.955894  23.702099
# 2272  14840.0  Greece    Nemea      NaN  2005.0  37.955894  23.702099
# 3113  30760.0  Greece    Nemea      NaN  2006.0  37.955894  23.702099
# 3202  32517.0  Greece    Nemea      NaN  2007.0  37.955894  23.702099
# 3237  33439.0  Greece    Nemea      NaN  2010.0  37.955894  23.702099
# 3270  34283.0  Greece    Nemea      NaN  2009.0  37.955894  23.702099
# 3619  44938.0  Greece    Nemea      NaN  2003.0  37.955894  23.702099
# 3815  51714.0  Greece    Nemea      NaN  2013.0  37.955894  23.702099
# 4691  99427.0  Greece    Nemea      NaN  2014.0  37.955894  23.702099
#
#       location  avg_temp  min_temp  max_temp  precipitation_in_mm  \
# 732        1.0       NaN       NaN       NaN                  NaN
# 1211       1.0       NaN       NaN       NaN                  NaN
# 1804       1.0       NaN       NaN       NaN                  NaN
# 1908       1.0       NaN       NaN       NaN                  NaN
# 2272       1.0       NaN       NaN       NaN                  NaN
# 3113       1.0       NaN       NaN       NaN                  NaN
# 3202       1.0       NaN       NaN       NaN                  NaN
# 3237       1.0       NaN       NaN       NaN                  NaN
# 3270       1.0       NaN       NaN       NaN                  NaN
# 3619       1.0       NaN       NaN       NaN                  NaN
# 3815       1.0       NaN       NaN       NaN                  NaN
# 4691       1.0       NaN       NaN       NaN                  NaN
#
#       wind_average_kmh  wind_peak_kmh  sun_minutes
# 732                NaN            NaN          NaN
# 1211               NaN            NaN          NaN
# 1804               NaN            NaN          NaN
# 1908               NaN            NaN          NaN
# 2272               NaN            NaN          NaN
# 3113               NaN            NaN          NaN
# 3202               NaN            NaN          NaN
# 3237               NaN            NaN          NaN
# 3270               NaN            NaN          NaN
# 3619               NaN            NaN          NaN
# 3815               NaN            NaN          NaN
# 4691               NaN            NaN          NaN

# %% [markdown]
# ### 7. Country = Austria & Province = Kremstal & Niederösterreich & Eisenberg
# - Check, whether the given geo-coordinates work. If it doesn't work, we should find another geo-coordinates and run the temperature code
#     - Geo-coordinates have been adjusted

# %%
wrong_geo = final_tb[(final_tb["province"] == "Kremstal") & (final_tb['avg_temp'].isna() ==True)]
fix_geo_data(wrong_geo, Point(48.409990,15.603840))
final_tb.update(wrong_geo)
# Out:
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
wrong_geo = final_tb[(final_tb["province"] == "Eisenberg") & (final_tb['avg_temp'].isna() ==True)]
fix_geo_data(wrong_geo, Point(46.903996384, 16.138499446))
final_tb.update(wrong_geo)
# Out:
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
wrong_geo = final_tb[(final_tb["province"] == "Niederösterreich") & (final_tb['avg_temp'].isna() ==True)]
fix_geo_data(wrong_geo, Point(48.33, 15.75))
final_tb.update(wrong_geo)
# Out:
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# ### 8. Country = Spain & Province = Catalonia & Andalucia
# - Check, whether the given geo-coordinates work. If it doesn't work, we should find another geo-coordinates and run the temperature code
#     - Geo-coordinates have been adjusted

# %%
wrong_geo = final_tb[(final_tb["province"] == "Catalonia") & (final_tb['avg_temp'].isna() ==True)]
fix_geo_data(wrong_geo, Point(41.390205,2.154007))
final_tb.update(wrong_geo)
# Out:
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
wrong_geo = final_tb[(final_tb["province"] == "Andalucia") & (final_tb['avg_temp'].isna() ==True)]
fix_geo_data(wrong_geo, Point(37.178055,-3.600833))
final_tb.update(wrong_geo)
# Out:
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# ### 9. Country = Italy & Province = Veneto
# - Check, whether the given geo-coordinates work. If it doesn't work, we should find another geo-coordinates and run the temperature code
#     - Geo-coordinates have been adjusted

# %%
wrong_geo = final_tb[(final_tb["province"] == "Veneto") & (final_tb['avg_temp'].isna() ==True)]
fix_geo_data(wrong_geo, Point(45.666668,12.250000))
final_tb.update(wrong_geo)
# Out:
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# ### 10. Country = France & Province = Champagne
# - Check, whether the given geo-coordinates work. If it doesn't work, we should find another geo-coordinates and run the temperature code
#     - Geo-coordinates have been adjusted

# %%
wrong_geo = final_tb[(final_tb["province"] == "Champagne") & (final_tb['avg_temp'].isna() ==True)]
fix_geo_data(wrong_geo, Point(48.026628, 0.333235))
final_tb.update(wrong_geo)
# Out:
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# ### 11. Country = US & Province = Arizona & Connecticut & Iowa & New Mexico & Texas & Vermont
# - Check, whether the given geo-coordinates work. If it doesn't work, we should find another geo-coordinates and run the temperature code
#     - Geo-coordinates have been adjusted

# %%
wrong_geo = final_tb[(final_tb["province"] == "Arizona") & (final_tb['avg_temp'].isna() ==True)]
fix_geo_data(wrong_geo, Point(34.048927,-111.093735))
final_tb.update(wrong_geo)
# Out:
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
wrong_geo = final_tb[(final_tb["province"] == "Connecticut") & (final_tb['avg_temp'].isna() ==True)]
fix_geo_data(wrong_geo, Point(41.599998,-72.699997))
final_tb.update(wrong_geo)
# Out:
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
wrong_geo = final_tb[(final_tb["province"] == "Iowa") & (final_tb['avg_temp'].isna() ==True)]
fix_geo_data(wrong_geo, Point(29.749907, -95.358421))
final_tb.update(wrong_geo)
# Out:
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
wrong_geo = final_tb[(final_tb["province"] == "New Mexico") & (final_tb['avg_temp'].isna() ==True)]
fix_geo_data(wrong_geo, Point(35.106766,-106.629181))
final_tb.update(wrong_geo)
# Out:
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
wrong_geo = final_tb[(final_tb["province"] == "Texas") & (final_tb['avg_temp'].isna() ==True)]
fix_geo_data(wrong_geo, Point(42.032974,-93.581543))
final_tb.update(wrong_geo)
# Out:
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
wrong_geo = final_tb[(final_tb["province"] == "Vermont") & (final_tb['avg_temp'].isna() ==True)]
fix_geo_data(wrong_geo, Point(44.000000,-72.699997))
final_tb.update(wrong_geo)
# Out:
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
final_tb['location'] = final_tb['location'].astype('int')
final_tb['year'] = final_tb['year'].astype('int')
final_tb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5074 entries, 0 to 5073
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   index                5074 non-null   float64
#  1   country              5074 non-null   object
#  2   province             5074 non-null   object
#  3   region_1             3937 non-null   object
#  4   year                 5074 non-null   int32
#  5   lat                  5074 non-null   float64
#  6   lon                  5074 non-null   float64
#  7   location             5074 non-null   int32
#  8   avg_temp             1722 non-null   float64
#  9   min_temp             1726 non-null   float64
#  10  max_temp             1725 non-null   float64
#  11  precipitation_in_mm  1412 non-null   float64
#  12  wind_average_kmh     1573 non-null   float64
#  13  wind_peak_kmh        53 non-null     float64
#  14  sun_minutes          123 non-null    float64
# dtypes: float64(10), int32(2), object(3)
# memory usage: 594.6+ KB

# %%
final_tb = get_temp_data(final_tb)

# %%
final_tb.isnull().sum()
# Out:
# index                     0
# country                   0
# province                  0
# region_1               1137
# year                      0
# lat                       0
# lon                       0
# location                  0
# avg_temp               1030
# min_temp               1026
# max_temp               1027
# precipitation_in_mm    1372
# wind_average_kmh       1226
# wind_peak_kmh          5000
# sun_minutes            4741
# dtype: int64

# %%
len(final_tb)
# Out:
# 5074

# %% [markdown]
# ### Save final table as csv

# %%
#from pathlib import Path
final_tb.to_csv('../Data/temp_table.csv')
